# %%
from selenium import webdriver as wb
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
from bs4 import BeautifulSoup as bs
import os
from urllib.request import urlretrieve

# %%
# 전체 게시물 크롤링

from selenium import webdriver as wb
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
from bs4 import BeautifulSoup as bs
import os
from urllib.request import urlretrieve

title_list = [] # 사업 명
application_list = [] # 지원분야
targetAge_list = [] # 대상연령
institution_list = [] # 기관명
contact_list = [] # 연락처
area_list = [] # 지역
recevingPeriod_list = [] # 접수기간
classification_list = [] # 기관구분
target_list = [] # 대상
startPeriod_list = [] # 창업기간
department_list = [] # 담당부서

            
driver = wb.Chrome()
driver.get('https://www.k-startup.go.kr/web/contents/bizpbanc-ongoing.do#none')

soup = bs(driver.page_source,'lxml')
page_count = soup.select('#bizPbancList > div > a')

for j in range(len(page_count)) :

    soup = bs(driver.page_source,'lxml')
    title_count = soup.select('.middle .tit')

    for i in range(len(title_count)) :
        title_click = driver.find_element(By.CSS_SELECTOR, f'#bizPbancList > ul > li:nth-child({i+1}) > div > div.right > div.middle > a')
        title_click.click()
        time.sleep(1)
        
        soup = bs(driver.page_source,'lxml')

        title = driver.find_element(By.CSS_SELECTOR, '#scrTitle').text
        application = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(1) > li:nth-child(1) > div > p.txt').text
        targetAge = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(1) > li:nth-child(2) > div > p.txt').text
        institution = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(1) > li:nth-child(3) > div > p.txt').text
        contact = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(1) > li:nth-child(4) > div > p.txt').text
        area = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(2) > li:nth-child(1) > div > p.txt').text
        receivingPeriod = driver.find_element(By.CSS_SELECTOR, '#rcptPeriod').text
        classification = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(2) > li:nth-child(3) > div > p.txt').text
        target = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(3) > li:nth-child(1) > div > p.txt').text
        startPeriod = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(3) > li:nth-child(2) > div > p.txt').text
        department = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(3) > li:nth-child(3) > div > p.txt').text    

        title_list.append(title)
        application_list.append(application)
        targetAge_list.append(targetAge)
        institution_list.append(institution)
        contact_list.append(contact)
        area_list.append(area)
        recevingPeriod_list.append(receivingPeriod)
        classification_list.append(classification)
        target_list.append(target)
        startPeriod_list.append(startPeriod)
        department_list.append(department)
        
        back_btn = driver.find_element(By.CSS_SELECTOR, "#contentViewHtml > div > div > div > div.lower_btn-wrap > a.btn_list")
        back_btn.click()

        time.sleep(1)
    page_click = driver.find_element(By.CSS_SELECTOR, f'#bizPbancList > div > a:nth-child({j+2})')
    page_click.click()
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [53], in <cell line: 22>()
#      59     back_btn.click()
#      61     time.sleep(1)
# ---> 62 page_click = driver.find_element(By.CSS_SELECTOR, f'#bizPbancList > div > a:nth-child({j+2})')
#      63 page_click.click()
#      64 time.sleep(1)
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:855, in WebDriver.find_element(self, by, value)
#     852     by = By.CSS_SELECTOR
#     853     value = '[name="%s"]' % value
# --> 855 return self.execute(Command.FIND_ELEMENT, {
#     856     'using': by,
#     857     'value': value})['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:428, in WebDriver.execute(self, driver_command, params)
#     426 response = self.command_executor.execute(driver_command, params)
#     427 if response:
# ...

# %%
# 자정 전으로 새로 추가된 게시물 크롤링

from selenium import webdriver as wb
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
from bs4 import BeautifulSoup as bs
import os
from urllib.request import urlretrieve

from datetime import datetime
from datetime import timedelta
import datetime

today = datetime.date.today()
yesterday = today - timedelta(days=1)
result = yesterday.strftime("%Y-%m-%d")

today_title_list = [] # 사업 명
today_application_list = [] # 지원분야
today_targetAge_list = [] # 대상연령
today_institution_list = [] # 기관명
today_contact_list = [] # 연락처
today_area_list = [] # 지역
today_recevingPeriod_list = [] # 접수기간
today_classification_list = [] # 기관구분
today_target_list = [] # 대상
today_startPeriod_list = [] # 창업기간
today_department_list = [] # 담당부서


        
driver = wb.Chrome()
driver.get('https://www.k-startup.go.kr/web/contents/bizpbanc-ongoing.do#none')

soup = bs(driver.page_source,'lxml')
page_count = soup.select('#bizPbancList > div > a')

for j in range(len(page_count)-1) :

    soup = bs(driver.page_source,'lxml')
    title_count = soup.select('.middle .tit')

    for i in range(len(title_count)) :
        date = driver.find_element(By.CSS_SELECTOR, f'#bizPbancList > ul > li:nth-child({i+1}) > div > div.right > div.bottom > span:nth-child(3)').text
        if result == date[5:] :
            title_click = driver.find_element(By.CSS_SELECTOR, f'#bizPbancList > ul > li:nth-child({i+1}) > div > div.right > div.middle > a')
            title_click.click()
            time.sleep(1)

            soup = bs(driver.page_source,'lxml')

            title = driver.find_element(By.CSS_SELECTOR, '#scrTitle').text
            application = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(1) > li:nth-child(1) > div > p.txt').text
            targetAge = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(1) > li:nth-child(2) > div > p.txt').text
            institution = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(1) > li:nth-child(3) > div > p.txt').text
            contact = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(1) > li:nth-child(4) > div > p.txt').text
            area = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(2) > li:nth-child(1) > div > p.txt').text
            receivingPeriod = driver.find_element(By.CSS_SELECTOR, '#rcptPeriod').text
            classification = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(2) > li:nth-child(3) > div > p.txt').text
            target = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(3) > li:nth-child(1) > div > p.txt').text
            startPeriod = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(3) > li:nth-child(2) > div > p.txt').text
            department = driver.find_element(By.CSS_SELECTOR, '#contentViewHtml > div > div > div > div.information_box-wrap > div.bg_box > ul:nth-child(3) > li:nth-child(3) > div > p.txt').text    

            today_title_list.append(title)
            today_application_list.append(application)
            today_targetAge_list.append(targetAge)
            today_institution_list.append(institution)
            today_contact_list.append(contact)
            today_area_list.append(area)
            today_recevingPeriod_list.append(receivingPeriod)
            today_classification_list.append(classification)
            today_target_list.append(target)
            today_startPeriod_list.append(startPeriod)
            today_department_list.append(department)

            back_btn = driver.find_element(By.CSS_SELECTOR, "#contentViewHtml > div > div > div > div.lower_btn-wrap > a.btn_list")
            back_btn.click()

            time.sleep(1)
    page_click = driver.find_element(By.CSS_SELECTOR, f'#bizPbancList > div > a:nth-child({j+2})')
    page_click.click()
    time.sleep(1)

# %%
# K-Startup 정부지원사업 첨부파일 크롤러

from selenium import webdriver as wb
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup as bs

import os
import time
import requests

from tqdm import trange
from urllib import request
from urllib.request import urlretrieve

site = "https://www.k-startup.go.kr/"
mydir ='C:/Users/smhrd/Desktop/지원사업/K-Startup'

if not os.path.isdir('C:/Users/smhrd/Desktop/지원사업') :
    # 폴더를 생성하는 코드작성
    os.mkdir('C:/Users/smhrd/Desktop/지원사업')
else :
    print("이미 폴더가 존재합니다")
    
driver = wb.Chrome()
driver.get('https://www.k-startup.go.kr/web/contents/bizpbanc-ongoing.do#none')

soup = bs(driver.page_source,'lxml')
page_count = soup.select('#bizPbancList > div > a')

try :
    for i in range(len(page_count)) :
        page_click = driver.find_element(By.CSS_SELECTOR, f'#bizPbancList > div > a:nth-child({i+1})')
        page_click.click()
        time.sleep(1)

        soup = bs(driver.page_source,'lxml')
        title_count = soup.select('.middle .tit')

        for i in range(len(title_count)) :
            title_click = driver.find_element(By.CSS_SELECTOR, f'#bizPbancList > ul > li:nth-child({i+1}) > div > div.right > div.middle > a')
            title_click.click()
            time.sleep(1)

            soup = bs(driver.page_source,'lxml')

            file = soup.select('.btn_down')
            file_type = soup.select('.file_bg')

            file_list = []
            for i in range(len(file)) :
                file_list.append(site+file[i]['href'])

            type_list = []
            for i in range(len(file_type)) :
                type_list.append(mydir+file_type[i].text)

            for i in range(len(file_list)) :
                urlretrieve(file_list[i],type_list[i])

                # time.sleep(5)
            back_btn = driver.find_element(By.CSS_SELECTOR, "#contentViewHtml > div > div > div > div.lower_btn-wrap > a.btn_list")
            back_btn.click()
            time.sleep(5)
except Exception as e :
    print(e)
# Out:
# HTTP Error 500: 500

# %%
# K-Startup 자정 전에 추가된 정부지원사업 첨부파일 크롤러

from selenium import webdriver as wb
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup as bs

import os
import time
import requests

from tqdm import trange
from urllib import request
from urllib.request import urlretrieve

from datetime import datetime
from datetime import timedelta
import datetime

today = datetime.date.today()
yesterday = today - timedelta(days=1)
result = yesterday.strftime("%Y-%m-%d")

site = "https://www.k-startup.go.kr/"
mydir ='C:/Users/smhrd/Desktop/지원사업/K-Startup'

if not os.path.isdir('C:/Users/smhrd/Desktop/지원사업') :
    # 폴더를 생성하는 코드작성
    os.mkdir('C:/Users/smhrd/Desktop/지원사업')
else :
    print("이미 폴더가 존재합니다")
    
driver = wb.Chrome()
driver.get('https://www.k-startup.go.kr/web/contents/bizpbanc-ongoing.do#none')

soup = bs(driver.page_source,'lxml')
page_count = soup.select('#bizPbancList > div > a')

try :
    for i in range(len(page_count)) :
        page_click = driver.find_element(By.CSS_SELECTOR, f'#bizPbancList > div > a:nth-child({i+1})')
        page_click.click()
        time.sleep(1)

        soup = bs(driver.page_source,'lxml')
        title_count = soup.select('.middle .tit')

        for i in range(len(title_count)) :
            date = driver.find_element(By.CSS_SELECTOR, f'#bizPbancList > ul > li:nth-child({i+1}) > div > div.right > div.bottom > span:nth-child(3)').text
            if result == date[5:] :
                title_click = driver.find_element(By.CSS_SELECTOR, f'#bizPbancList > ul > li:nth-child({i+1}) > div > div.right > div.middle > a')
                title_click.click()

                soup = bs(driver.page_source,'lxml')

                file = soup.select('.btn_down')
                file_type = soup.select('.file_bg')

                file_list = []
                for i in range(len(file)) :
                    file_list.append(site+file[i]['href'])

                type_list = []
                for i in range(len(file_type)) :
                    type_list.append(mydir+file_type[i].text)

                for i in range(len(file_list)) :
                    urlretrieve(file_list[i],type_list[i])
                
                back_btn = driver.find_element(By.CSS_SELECTOR, "#contentViewHtml > div > div > div > div.lower_btn-wrap > a.btn_list")
                back_btn.click()
                time.sleep(3)

except Exception as e :
    print(e)
